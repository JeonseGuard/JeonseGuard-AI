# %%
# 데이터 불러오기
import pandas as pd

file_path = "/content/drive/MyDrive/JeonseGuard/202501_아파트_전세_실거래가.csv" # CSV 파일 경로 지정
df = pd.read_csv(file_path, encoding='cp949') # CP949 인코딩

# %%
# 상위 5개 확인
df.head()
# Out:
#    NO                    시군구      번지    본번  부번            단지명 전월세구분  전용면적(㎡)  \
# 0   1       경상남도 창원시 진해구 용원동  1337-3  1337   3  부산신항사랑으로부영5단지    전세  84.9933
# 1   2       경상남도 창원시 진해구 용원동    1338  1338   0  부산신항사랑으로부영6단지    전세  84.9933
# 2   3       경상남도 창원시 진해구 용원동    1338  1338   0  부산신항사랑으로부영6단지    전세  84.9933
# 3   4  전북특별자치도 전주시 덕진구 송천동2가    1342  1342   0  에코시티데시앙네스트3블럭    월세  75.8452
# 4   5       충청남도 천안시 서북구 두정동    2078  2078   0   두정역효성해링턴플레이스    전세  59.8600
#
#      계약년월  계약일  ... 월세금(만원)   층  건축년도      도로명           계약기간 계약구분 갱신요구권 사용  \
# 0  202501   31  ...       0  11  2019  신항5로 43  202502~202602   갱신        -
# 1  202501   31  ...       0   3  2019  신항5로 56  202503~202603   갱신        -
# 2  202501   31  ...       0   8  2019  신항5로 56  202502~202602   갱신        -
# 3  202501   31  ...      32   2  2020   세병로 90  202503~202703   갱신        -
# 4  202501   31  ...       0  28  2020  봉정로 324  202503~202703   신규        -
#
#   종전계약 보증금(만원) 종전계약 월세(만원)  주택유형
# ...

# %%
# 컬럼명 확인
print(df.columns)
# Out:
# Index(['NO', '시군구', '번지', '본번', '부번', '단지명', '전월세구분', '전용면적(㎡)', '계약년월', '계약일',
#        '보증금(만원)', '월세금(만원)', '층', '건축년도', '도로명', '계약기간', '계약구분', '갱신요구권 사용',
#        '종전계약 보증금(만원)', '종전계약 월세(만원)', '주택유형'],
#       dtype='object')

# %%
# 특정 컬럼 값만 확인
df["보증금(만원)"].head()
# Out:
# 0    12,833
# 1    12,833
# 2    12,833
# 3    14,302
# 4    26,000
# Name: 보증금(만원), dtype: object

# %%
# 전세만 필터링
jeonse_df = df[df["전월세구분"] == "전세"]
jeonse_df.head()
# Out:
#    NO                  시군구      번지    본번  부번            단지명 전월세구분   전용면적(㎡)  \
# 0   1     경상남도 창원시 진해구 용원동  1337-3  1337   3  부산신항사랑으로부영5단지    전세   84.9933
# 1   2     경상남도 창원시 진해구 용원동    1338  1338   0  부산신항사랑으로부영6단지    전세   84.9933
# 2   3     경상남도 창원시 진해구 용원동    1338  1338   0  부산신항사랑으로부영6단지    전세   84.9933
# 4   5     충청남도 천안시 서북구 두정동    2078  2078   0   두정역효성해링턴플레이스    전세   59.8600
# 5   6  경기도 용인시 처인구 포곡읍 둔전리     449   449   0      용인포곡삼성쉐르빌    전세  115.4429
#
#      계약년월  계약일  ... 월세금(만원)   층  건축년도      도로명           계약기간 계약구분 갱신요구권 사용  \
# 0  202501   31  ...       0  11  2019  신항5로 43  202502~202602   갱신        -
# 1  202501   31  ...       0   3  2019  신항5로 56  202503~202603   갱신        -
# 2  202501   31  ...       0   8  2019  신항5로 56  202502~202602   갱신        -
# 4  202501   31  ...       0  28  2020  봉정로 324  202503~202703   신규        -
# 5  202501   31  ...       0   9  2012  포곡로 159  202502~202602   신규        -
#
#   종전계약 보증금(만원) 종전계약 월세(만원)  주택유형
# ...

# %%
# 변경 매핑 딕셔너리 정의
renamed_columns = {
    "시군구": "address",
    "본번": "bun",
    "부번": "ji",
    "층": "floor",
    "전월세구분": "rent_type",
    "계약년월": "contract_year_month",
    "보증금(만원)": "price",
    "주택유형": "housing_type"
}

# %%
# 매핑에 해당하는 컬럼만 필터링
df = df.rename(columns=renamed_columns)
changed_df = df[list(renamed_columns.values())]
changed_df.head()
# Out:
#                  address   bun  ji  floor rent_type  contract_year_month  \
# 0       경상남도 창원시 진해구 용원동  1337   3     11        전세               202501
# 1       경상남도 창원시 진해구 용원동  1338   0      3        전세               202501
# 2       경상남도 창원시 진해구 용원동  1338   0      8        전세               202501
# 3  전북특별자치도 전주시 덕진구 송천동2가  1342   0      2        월세               202501
# 4       충청남도 천안시 서북구 두정동  2078   0     28        전세               202501
#
#     price housing_type
# 0  12,833          아파트
# 1  12,833          아파트
# 2  12,833          아파트
# 3  14,302          아파트
# 4  26,000          아파트

# %%
# rent_type 컬럼에서 "전세"만 필터링
jeonse_df = changed_df[changed_df["rent_type"] == "전세"].reset_index(drop=True)
jeonse_df.head()
# Out:
#                address   bun  ji  floor rent_type  contract_year_month  \
# 0     경상남도 창원시 진해구 용원동  1337   3     11        전세               202501
# 1     경상남도 창원시 진해구 용원동  1338   0      3        전세               202501
# 2     경상남도 창원시 진해구 용원동  1338   0      8        전세               202501
# 3     충청남도 천안시 서북구 두정동  2078   0     28        전세               202501
# 4  경기도 용인시 처인구 포곡읍 둔전리   449   0      9        전세               202501
#
#     price housing_type
# 0  12,833          아파트
# 1  12,833          아파트
# 2  12,833          아파트
# 3  26,000          아파트
# 4  32,000          아파트

# %%
# price 타입 확인
print("Before conversion:", jeonse_df["price"].dtype)
# Out:
# Before conversion: object

# %%
# 쉼표 제거 및 문자열을 정수로 변환
jeonse_df["price"] = (
    jeonse_df["price"]
    .astype(str) # 문자열로 변환 (안전)
    .str.replace(",", "") # 쉼표 제거
    .astype(int) # 정수형으로 변환
    * 10000 # 만원 → 원 변환
)

# %%
# 변환된 price 타입 확인
print("After conversion:", jeonse_df["price"].dtype)
# Out:
# After conversion: int64

# %%
# 변환된 price 컬럼 확인
print(jeonse_df[["price"]].head())
# Out:
#        price
# 0  128330000
# 1  128330000
# 2  128330000
# 3  260000000
# 4  320000000

# %%
# price 컬럼의 값을 쉼표가 포함된 문자열로 변환
jeonse_df["price"] = jeonse_df["price"].apply(lambda x: format(x, ","))
jeonse_df.head()
# Out:
#                address   bun  ji  floor rent_type  contract_year_month  \
# 0     경상남도 창원시 진해구 용원동  1337   3     11        전세               202501
# 1     경상남도 창원시 진해구 용원동  1338   0      3        전세               202501
# 2     경상남도 창원시 진해구 용원동  1338   0      8        전세               202501
# 3     충청남도 천안시 서북구 두정동  2078   0     28        전세               202501
# 4  경기도 용인시 처인구 포곡읍 둔전리   449   0      9        전세               202501
#
#          price housing_type
# 0  128,330,000          아파트
# 1  128,330,000          아파트
# 2  128,330,000          아파트
# 3  260,000,000          아파트
# 4  320,000,000          아파트

# %%
# 결측치 확인
missing_counts = jeonse_df.isnull().sum()
print("📌 결측치가 있는 컬럼: ", missing_counts[missing_counts > 0])
# Out:
# 📌 결측치가 있는 컬럼:  Series([], dtype: int64)

# %%
# INSERT 구문 생성
insert_header = """INSERT INTO jeonse_transaction_apartment (address, bun, ji, floor, rent_type, contract_year_month, price, housing_type, created_at, updated_at)
VALUES """

# %%
# 행별로 SQL 값 문자열 생성
values = []

# %%
# 각 행을 values 리스트에 추가
for _, row in jeonse_df.iterrows():
    values.append(f"('{row['address']}', '{row['bun']}', '{row['ji']}', '{row['floor']}', '{row['rent_type']}', '{row['contract_year_month']}', '{row['price']}', '{row['housing_type']}', NOW(), NOW())")

# %%
# INSERT 구문 상위 5개만 출력
preview_sql = insert_header + ",\n       ".join(values[:5]) + ";"
print(preview_sql)
# Out:
# INSERT INTO jeonse_transaction_apartment (address, bun, ji, floor, rent_type, contract_year_month, price, housing_type, created_at, updated_at)
# VALUES ('경상남도 창원시 진해구 용원동', '1337', '3', '11', '전세', '202501', '128,330,000', '아파트', NOW(), NOW()),
#        ('경상남도 창원시 진해구 용원동', '1338', '0', '3', '전세', '202501', '128,330,000', '아파트', NOW(), NOW()),
#        ('경상남도 창원시 진해구 용원동', '1338', '0', '8', '전세', '202501', '128,330,000', '아파트', NOW(), NOW()),
#        ('충청남도 천안시 서북구 두정동', '2078', '0', '28', '전세', '202501', '260,000,000', '아파트', NOW(), NOW()),
#        ('경기도 용인시 처인구 포곡읍 둔전리', '449', '0', '9', '전세', '202501', '320,000,000', '아파트', NOW(), NOW());

# %%
# INSERT 구문 조립
insert_sql = insert_header + ",\n       ".join(values) + ";"

# %%
# 파일 저장
file_name = "V20__insert_jeonse_transaction_apartment_202501.sql"

with open(file_name, "w", encoding="utf-8") as f:
    f.write(insert_sql)

print(f"{file_name} 파일이 생성되었습니다.")
# Out:
# V20__insert_jeonse_transaction_apartment_202501.sql 파일이 생성되었습니다.
